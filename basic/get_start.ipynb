# %% [markdown]
# pyspedasをインストール

# %%
# %pip install pyspedas
# %matplotlib widget
# Out:
# Collecting pyspedas
#   Using cached pyspedas-1.4.37-py3-none-any.whl (1.1 MB)
# Collecting astropy
#   Using cached astropy-5.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (10.1 MB)
# Requirement already satisfied: numpy>=1.19.5 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from pyspedas) (1.24.3)
# Collecting cdflib>=0.4.3
#   Using cached cdflib-1.0.4-py3-none-any.whl (72 kB)
# Collecting netCDF4>=1.6.2
#   Using cached netCDF4-1.6.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
# Collecting pywavelets
#   Using cached PyWavelets-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
# Collecting pytplot-mpl-temp>=2.1.37
#   Using cached pytplot_mpl_temp-2.1.39-py3-none-any.whl (1.8 MB)
# Collecting requests
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting cdasws>=1.7.24
#   Using cached cdasws-1.7.42-py3-none-any.whl (38 kB)
# Collecting geopack>=1.0.10
#   Using cached geopack-1.0.10-py3-none-any.whl (114 kB)
# Collecting viresclient
#   Using cached viresclient-0.11.1-py3-none-any.whl (96 kB)
# Collecting hapiclient>=0.2.2
#   Using cached hapiclient-0.2.5-py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from cdasws>=1.7.24->pyspedas) (2.8.2)
# Collecting scipy
#   Using cached scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
# Collecting joblib
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Collecting pandas>=0.23
#   Using cached pandas-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
# Collecting urllib3
#   Using cached urllib3-2.0.3-py3-none-any.whl (123 kB)
# Collecting isodate>=0.6.0
#   Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Collecting cftime
#   Using cached cftime-1.6.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Collecting certifi
#   Using cached certifi-2023.5.7-py3-none-any.whl (156 kB)
# Requirement already satisfied: matplotlib>=3.4 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from pytplot-mpl-temp>=2.1.37->pyspedas) (3.7.1)
# Collecting xarray
#   Using cached xarray-2023.5.0-py3-none-any.whl (994 kB)
# Collecting cdflib>=0.4.3
#   Using cached cdflib-0.4.9-py3-none-any.whl (72 kB)
# Collecting bokeh<3.0,>=1.1
#   Using cached bokeh-2.4.3-py3-none-any.whl (18.5 MB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (199 kB)
# Requirement already satisfied: idna<4,>=2.5 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from requests->pyspedas) (3.4)
# Requirement already satisfied: PyYAML>=3.13 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from astropy->pyspedas) (6.0)
# Collecting pyerfa>=2.0
#   Using cached pyerfa-2.0.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (741 kB)
# Requirement already satisfied: packaging>=19.0 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from astropy->pyspedas) (23.1)
# Collecting tqdm>=4.23.0
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Requirement already satisfied: Jinja2>=2.10 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from viresclient->pyspedas) (3.1.2)
# Collecting tables>=3.4.4
#   Using cached tables-3.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
# Requirement already satisfied: tornado>=5.1 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from bokeh<3.0,>=1.1->pytplot-mpl-temp>=2.1.37->pyspedas) (6.3.2)
# Requirement already satisfied: pillow>=7.1.0 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from bokeh<3.0,>=1.1->pytplot-mpl-temp>=2.1.37->pyspedas) (9.5.0)
# Collecting typing-extensions>=3.10.0
#   Using cached typing_extensions-4.6.3-py3-none-any.whl (31 kB)
# Requirement already satisfied: six in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from isodate>=0.6.0->hapiclient>=0.2.2->pyspedas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from Jinja2>=2.10->viresclient->pyspedas) (2.1.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from matplotlib>=3.4->pytplot-mpl-temp>=2.1.37->pyspedas) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from matplotlib>=3.4->pytplot-mpl-temp>=2.1.37->pyspedas) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from matplotlib>=3.4->pytplot-mpl-temp>=2.1.37->pyspedas) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from matplotlib>=3.4->pytplot-mpl-temp>=2.1.37->pyspedas) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages (from matplotlib>=3.4->pytplot-mpl-temp>=2.1.37->pyspedas) (4.40.0)
# Collecting pytz>=2020.1
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting blosc2~=2.0.0
#   Using cached blosc2-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.9 MB)
# Collecting cython>=0.29.21
#   Using cached Cython-0.29.35-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Collecting numexpr>=2.6.2
#   Using cached numexpr-2.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (381 kB)
# Collecting py-cpuinfo
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting msgpack
#   Using cached msgpack-1.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (316 kB)
# Installing collected packages: pytz, py-cpuinfo, msgpack, urllib3, tzdata, typing-extensions, tqdm, scipy, pywavelets, pyerfa, numexpr, joblib, isodate, cython, charset-normalizer, cftime, certifi, cdflib, blosc2, tables, requests, pandas, netCDF4, geopack, bokeh, astropy, xarray, hapiclient, cdasws, viresclient, pytplot-mpl-temp, pyspedas
# Successfully installed astropy-5.3 blosc2-2.0.0 bokeh-2.4.3 cdasws-1.7.42 cdflib-0.4.9 certifi-2023.5.7 cftime-1.6.2 charset-normalizer-3.1.0 cython-0.29.35 geopack-1.0.10 hapiclient-0.2.5 isodate-0.6.1 joblib-1.2.0 msgpack-1.0.5 netCDF4-1.6.4 numexpr-2.8.4 pandas-2.0.2 py-cpuinfo-9.0.0 pyerfa-2.0.0.3 pyspedas-1.4.37 pytplot-mpl-temp-2.1.39 pytz-2023.3 pywavelets-1.4.1 requests-2.31.0 scipy-1.10.1 tables-3.8.0 tqdm-4.65.0 typing-extensions-4.6.3 tzdata-2023.3 urllib3-2.0.3 viresclient-0.11.1 xarray-2023.5.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# pyspedasモジュールをインストール

# %%
import pyspedas

# %% [markdown]
# trで時間を指定してmgfデータをロード

# %%
tr = ['2017-03-27', '2017-03-28']

from pyspedas.erg import mgf
mgf(trange = tr)
# Out:
# 15-Jun-23 18:58:57: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mgf/l2/8sec/2017/03/
# 15-Jun-23 18:58:57: File is current: erg_data/satellite/erg/mgf/l2/8sec/2017/03/erg_mgf_l2_8sec_20170327_v03.04.cdf
# 15-Jun-23 18:58:57: /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:310: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if ydata[ydata == var_atts["FILLVAL"]].size != 0:
#
# 15-Jun-23 18:58:57: /home/jackkooki/Document/arase_data_user_tohoku/.venv/lib/python3.10/site-packages/pytplot/importers/cdf_to_tplot.py:316: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   ydata[ydata == var_atts["FILLVAL"]] = 0
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Magnetic Field Experiment (MGF) Level 2 spin-averaged magnetic field data
#
# Information about ERG MGF
#
# PI:  Ayako Matsuoka
# Affiliation: Data Analysis Center for Geomagnetism and Space Magnetism, Graduate School of Science, Kyoto University, Kitashirakawa-Oiwake Cho, Sakyo-ku Kyoto 606-8502, Japan
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of MGF L2: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Mgf
# Contact: erg_mgf_info at isee.nagoya-u.ac.jp
# **************************************************************************
# ['erg_mgf_l2_epoch_8sec',
#  'erg_mgf_l2_mag_8sec_dsi',
#  'erg_mgf_l2_mag_8sec_gse',
#  'erg_mgf_l2_mag_8sec_gsm',
#  'erg_mgf_l2_mag_8sec_sm',
#  'erg_mgf_l2_magt_8sec',
#  'erg_mgf_l2_rmsd_8sec_dsi',
#  'erg_mgf_l2_rmsd_8sec_gse',
#  'erg_mgf_l2_rmsd_8sec_gsm',
#  'erg_mgf_l2_rmsd_8sec_sm',
#  'erg_mgf_l2_rmsd_8sec',
#  'erg_mgf_l2_n_rmsd_8sec',
#  'erg_mgf_l2_dyn_rng_8sec',
#  'erg_mgf_l2_quality_8sec',
#  'erg_mgf_l2_quality_8sec_gc',
#  'erg_mgf_l2_igrf_8sec_dsi',
#  'erg_mgf_l2_igrf_8sec_gse',
#  'erg_mgf_l2_igrf_8sec_gsm',
#  'erg_mgf_l2_igrf_8sec_sm']

# %% [markdown]
# その場のサイクロトロン周波数を計算してみよう

# %% [markdown]
# サイクロトロン周波数は\
# $\omega_{ce}=\frac{e\cdot B}{m_e}$\
# で計算できる。\
# 磁場はmgfデータから持ってきたい。

# %% [markdown]
# まずは必要なモジュールをインストール\
# 電荷素量や電子質量はplasma_paramsに入っている

# %%
import numpy as np #計算したいときはnumpyをimport
import pytplot #pytplotはpythonで時間プロット
import plasma_prams as pp #定数をまとめたモジュール

# %% [markdown]
# データを数値として読み込むには主に二つの方法がある

# %% [markdown]
# 一つ目はpytplotモジュールののdata_quantsを使う方法

# %%
pytplot.data_quants['erg_mgf_l2_magt_8sec'] #磁場データを取得
# Out:
# <xarray.DataArray 'erg_mgf_l2_magt_8sec' (time: 10812)>
# array([349.97209299, 349.32177136, 348.69561499, ..., 209.22848032,
#        209.46040549, 209.87081885])
# Coordinates:
#   * time     (time) datetime64[ns] 2017-03-26T23:59:58.621162 ... 2017-03-27T...
# Attributes:
#     CDF:           {'VATT': {'FIELDNAM': 'Bt', 'CATDESC': '8 sec resolution t...
#     data_att:      {'coord_sys': '', 'units': 'nT', 'depend_1_units': 'nT', '...
#     plot_options:  {'xaxis_opt': {'axis_label': 'Time', 'crosshair': 'X', 'x_...

# %% [markdown]
# ちなみに、araseデータはxarrayという座標軸名を定義できるデータに入っている\
# 磁場は一つの時間に対して一つの値が入っているので'time'という座標軸が存在している

# %% [markdown]
# もう一つの方法はget_dataを使う方法\
# この方法だと単にarrayとしてデータを取り出せる\
# timesとyのarray

# %%
pytplot.get_data('erg_mgf_l2_magt_8sec')
# Out:
# variable(times=array([1.49057280e+09, 1.49057280e+09, 1.49057281e+09, ...,
#        1.49065917e+09, 1.49065918e+09, 1.49065919e+09]), y=array([349.97209299, 349.32177136, 348.69561499, ..., 209.22848032,
#        209.46040549, 209.87081885]))

# %% [markdown]
# それぞれのデータをいじってみる

# %%
B = pytplot.data_quants['erg_mgf_l2_magt_8sec']

# %%
B['time']
# Out:
# <xarray.DataArray 'time' (time: 10812)>
# array(['2017-03-26T23:59:58.621162000', '2017-03-27T00:00:01.713156000',
#        '2017-03-27T00:00:09.708524000', ..., '2017-03-27T23:59:29.580020000',
#        '2017-03-27T23:59:37.559818000', '2017-03-27T23:59:45.555189000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2017-03-26T23:59:58.621162 ... 2017-03-27T...

# %%
B[0]
# Out:
# <xarray.DataArray 'erg_mgf_l2_magt_8sec' ()>
# array(349.97209299)
# Coordinates:
#     time     datetime64[ns] 2017-03-26T23:59:58.621162
# Attributes:
#     CDF:           {'VATT': {'FIELDNAM': 'Bt', 'CATDESC': '8 sec resolution t...
#     data_att:      {'coord_sys': '', 'units': 'nT', 'depend_1_units': 'nT', '...
#     plot_options:  {'xaxis_opt': {'axis_label': 'Time', 'crosshair': 'X', 'x_...

# %%
B_array = pytplot.get_data('erg_mgf_l2_magt_8sec')

# %%
B_array[:][0] #B_arrayの0番目の要素=time
# Out:
# array([1.49057280e+09, 1.49057280e+09, 1.49057281e+09, ...,
#        1.49065917e+09, 1.49065918e+09, 1.49065919e+09])

# %%
B_array[:][1] #B_arrayの1番目の要素=B
# Out:
# array([349.97209299, 349.32177136, 348.69561499, ..., 209.22848032,
#        209.46040549, 209.87081885])

# %%
B_array[0][:]
# Out:
# array([1.49057280e+09, 1.49057280e+09, 1.49057281e+09, ...,
#        1.49065917e+09, 1.49065918e+09, 1.49065919e+09])

# %%
B_array[0][0]
# Out:
# 1490572798.621162

# %%
B_array[0][1]
# Out:
# 1490572801.713156

# %%
B_array[1][0]
# Out:
# 349.97209298515725

# %%
B_array[1][1]
# Out:
# 349.32177136306717

# %% [markdown]
# 実際に計算してみよう

# %%
fc = (pp.Q*B/pp.ME)/2/np.pi

# %% [markdown]
# データを格納してプロット

# %%
pytplot.store_data('fc', data={'x': B['time'], 'y': fc})
# Out:
# True

# %%
pytplot.options('fc', opt_dict={'ytitle': 'fc [Hz]', 'ylog': True})
pytplot.tplot(['fc','erg_mgf_l2_magt_8sec'])
